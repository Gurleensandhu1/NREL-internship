# %% [markdown]
# #  Getting started

# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt

# %%
filenames = glob.glob("data/*/results.csv")

# %%
filenames
# Out:
# ['data\\PPO_MergeEnvironment-v0_bb984c82_2021-06-24_21-30-480zwyot0z\\results.csv',
#  'data\\PPO_MergeEnvironment-v0_bb9bae7c_2021-06-24_21-30-48lpz8cn3t\\results.csv']

# %%
df0 = pd.read_csv(filenames[0])
df0.head()
# Out:
#    action:bottom  action:inflow_highway  action:inflow_merge  action:left  \
# 0      24.782276               0.000000            24.782276     0.000000
# 1       9.060183              27.838340             9.060183    27.838340
# 2      18.054904              12.540195            18.054904    12.540195
# 3      30.000000               6.748676            30.000000     6.748676
# 4      16.437545               0.000000            16.437545     0.000000
#
#    outflow:bottom  outflow:center  outflow:left    reward  speed:bottom  \
# 0            1080            1080             0  0.737853      2.785301
# 1             360            2250          1980  0.674526      1.557209
# 2             360            1710          1350  0.646252      0.647248
# 3             450            1710          1260  0.685994      1.152700
# 4            1080            1350            90  0.795664      3.093019
#
#    speed:center  speed:left  state:speed:bottom  state:speed:left  step
# ...

# %%
plt.plot(df0["speed:left"])
plt.plot(df0["speed:center"])
plt.plot(df0["speed:bottom"])
plt.legend(['speed:left','speed:center','speed:bottom'])
plt.title("Speed time series")
plt.show()

# %%
df1 = pd.read_csv(filenames[1])
df1.head()
# Out:
#    action:bottom  action:inflow_highway  action:inflow_merge  action:left  \
# 0      17.997034              13.666177            17.997034    13.666177
# 1      13.126401               0.000000            13.126401     0.000000
# 2      25.985437              17.751053            25.985437    17.751053
# 3      25.498731               0.000000            25.498731     0.000000
# 4      19.973762               4.123782            19.973762     4.123782
#
#    outflow:bottom  outflow:center  outflow:left    reward  speed:bottom  \
# 0             135            2160          2025  0.522024      0.386428
# 1            1125            1170            90  0.807811      3.270185
# 2             135            2700          2520  0.540385      0.571167
# 3            1125            1170            90  0.807811      3.320557
# 4             855            1350           540  0.790405      2.519716
#
#    speed:center  speed:left  state:speed:bottom  state:speed:left  step
# ...

# %%
plt.plot(df1["speed:left"])
plt.plot(df1["speed:center"])
plt.plot(df1["speed:bottom"])
plt.legend(['speed:left','speed:center','speed:bottom'])
plt.title("Speed time series")
plt.show()

# %%
plt.plot(df0["speed:bottom"])
plt.plot(df1["speed:bottom"])
plt.legend(['speed:bottom 1','speed:bottom 2'])
plt.title("Speed:bottom comparison from each file")
plt.show()

# %%
plt.plot(df0["speed:left"])
plt.plot(df1["speed:left"])
plt.legend(['speed:left 1','speed:left 2'])
plt.title("Speed:left comparison from each file")
plt.show()

# %%
plt.hist(df0["outflow:center"])
plt.hist(df1["outflow:center"])
plt.legend(['outflow:center 1','outflow:center 2'])
plt.title("outflow:center comparison from each file")
plt.show()

# %%
plt.hist(df0["outflow:bottom"])
plt.hist(df1["outflow:bottom"])
plt.legend(['outflow:bottom 1','outflow:bottom 2'])
plt.title("outflow:bottom comparison from each file")
plt.show()

# %%
plt.hist(df0["outflow:left"])
plt.hist(df1["outflow:left"])
plt.legend(['outflow:left 1','outflow:left 2'])
plt.title("outflow:left comparison from each file")
plt.show()

# %%
plt.hist(df0["speed:left"])
plt.hist(df0["speed:center"])
plt.hist(df0["speed:bottom"])
plt.legend(['speed:left','speed:center','speed:bottom'])
plt.title("Histogram plot for speed from file 1")
plt.show()

# %%
plt.hist(df1["speed:left"])
plt.hist(df1["speed:center"])
plt.hist(df1["speed:bottom"])
plt.legend(['speed:left','speed:center','speed:bottom'])
plt.title("Histogram plot for speed from file 2")
plt.show()

# %%
plt.hist(df0["speed:center"])
plt.hist(df1["speed:center"])
plt.legend(['speed:center 1','speed:center 2'])
plt.title("speed:center comparison from each file")
plt.show()

# %%
plt.hist(df0["speed:left"])
plt.hist(df1["speed:left"])
plt.legend(['speed:left 1','speed:left 2'])
plt.title("speed:left comparison from each file")
plt.show()

# %%
plt.hist(df0["speed:bottom"])
plt.hist(df1["speed:bottom"])
plt.legend(['speed:bottom 1','speed:bottom 2'])
plt.title("speed:bottom comparison from each file")
plt.show()

# %%
fig_1 = plt.figure(1, figsize=(20, 4.8))
speed_file1 = fig_1.add_subplot(122)
speed_file2 = fig_1.add_subplot(121)

speed_file1.hist(df0["speed:bottom"])
speed_file2.plot(df0["speed:bottom"])
plt.show()

# %%
fig_1 = plt.figure(1, figsize=(20, 4.8))
speed_file1 = fig_1.add_subplot(122)
speed_file2 = fig_1.add_subplot(121)

speed_file1.hist(df1["speed:bottom"])
speed_file2.plot(df1["speed:bottom"])
plt.show()

# %%
fig_1 = plt.figure(1, figsize=(20, 4.8))
speed_file1 = fig_1.add_subplot(122)
speed_file2 = fig_1.add_subplot(121)

speed_file1.hist(df0["speed:center"])
speed_file2.plot(df0["speed:center"])
plt.show()

# %%
fig_1 = plt.figure(1, figsize=(20, 4.8))
speed_file1 = fig_1.add_subplot(122)
speed_file2 = fig_1.add_subplot(121)

speed_file1.hist(df1["speed:center"])
speed_file2.plot(df1["speed:center"])
plt.show()

# %%
fig_1 = plt.figure(1, figsize=(20, 4.8))
speed_file1 = fig_1.add_subplot(122)
speed_file2 = fig_1.add_subplot(121)

speed_file1.hist(df0["speed:left"])
speed_file2.plot(df0["speed:left"])
plt.show()

# %%
fig_1 = plt.figure(1, figsize=(20, 4.8))
speed_file1 = fig_1.add_subplot(122)
speed_file2 = fig_1.add_subplot(121)

speed_file1.hist(df1["speed:left"])
speed_file2.plot(df1["speed:left"])
plt.show()

# %%
fig_1 = plt.figure(1, figsize=(20, 4.8))
speed_file1 = fig_1.add_subplot(122)
speed_file2 = fig_1.add_subplot(121)

speed_file1.hist(df0["speed:left"])
speed_file2.plot(df0["speed:left"])
speed_file1.hist(df0["speed:bottom"])
speed_file2.plot(df0["speed:bottom"])
speed_file1.hist(df0["speed:center"])
speed_file2.plot(df0["speed:center"])
plt.legend(['speed:left','speed:center','speed:bottom'])
plt.title("speed:left, speed:bottom, and speed:center comparison from each file 1")
plt.show()

# %%
fig_1 = plt.figure(1, figsize=(20, 4.8))
speed_file1 = fig_1.add_subplot(122)
speed_file2 = fig_1.add_subplot(121)

speed_file1.hist(df1["speed:left"])
speed_file2.plot(df1["speed:left"])
speed_file1.hist(df1["speed:bottom"])
speed_file2.plot(df1["speed:bottom"])
speed_file1.hist(df1["speed:center"])
speed_file2.plot(df1["speed:center"])
plt.legend(['speed:left','speed:center','speed:bottom'])
plt.title("speed:left, speed:bottom, and speed:center comparison from each file 2")
plt.show()

# %%
fig_1 = plt.figure(1, figsize=(20, 4.8))
speed_file1 = fig_1.add_subplot(122)
speed_file2 = fig_1.add_subplot(121)

speed_file1.hist(df0["speed:left"])
speed_file2.plot(df0["speed:left"])
speed_file1.hist(df0["speed:bottom"])
speed_file2.plot(df0["speed:bottom"])
speed_file1.hist(df0["speed:center"])
speed_file2.plot(df0["speed:center"])
speed_file1.hist(df1["speed:left"])
speed_file2.plot(df1["speed:left"])
speed_file1.hist(df1["speed:bottom"])
speed_file2.plot(df1["speed:bottom"])
speed_file1.hist(df1["speed:center"])
speed_file2.plot(df1["speed:center"])
plt.legend(['speed:left','speed:center','speed:bottom'])
plt.title("speed:left, speed:bottom, and speed:center comparison from both files")
plt.show()

# %%
df0.rolling(10).mean()
# Out:
#      action:bottom  action:inflow_highway  action:inflow_merge  action:left  \
# 0              NaN                    NaN                  NaN          NaN
# 1              NaN                    NaN                  NaN          NaN
# 2              NaN                    NaN                  NaN          NaN
# 3              NaN                    NaN                  NaN          NaN
# 4              NaN                    NaN                  NaN          NaN
# ..             ...                    ...                  ...          ...
# 123      15.200487               8.612971            15.200487     8.612971
# 124      14.877440               9.211591            14.877440     9.211591
# 125      15.081904               8.478275            15.081904     8.478275
# 126      17.473302               9.977200            17.473302     9.977200
# 127      18.168412               9.977200            18.168412     9.977200
#
# ...

# %%
df1.rolling(10).mean()
# Out:
#     action:bottom  action:inflow_highway  action:inflow_merge  action:left  \
# 0             NaN                    NaN                  NaN          NaN
# 1             NaN                    NaN                  NaN          NaN
# 2             NaN                    NaN                  NaN          NaN
# 3             NaN                    NaN                  NaN          NaN
# 4             NaN                    NaN                  NaN          NaN
# ..            ...                    ...                  ...          ...
# 59      24.618641               3.375597            24.618641     3.375597
# 60      25.045636               3.375597            25.045636     3.375597
# 61      22.949715               4.619235            22.949715     4.619235
# 62      21.590380               4.188485            21.590380     4.188485
# 63      18.590380               7.125848            18.590380     7.125848
#
# ...

# %%
plt.plot(df0.rolling(10).mean()["speed:left"])
plt.plot(df0.rolling(10).mean()["speed:center"])
plt.plot(df0.rolling(10).mean()["speed:bottom"])
plt.legend(['speed:left','speed:center','speed:bottom'])
plt.title("Speed time series")
plt.show()

# %%
plt.plot(df1.rolling(10).mean()["speed:left"])
plt.plot(df1.rolling(10).mean()["speed:center"])
plt.plot(df1.rolling(10).mean()["speed:bottom"])
plt.legend(['speed:left','speed:center','speed:bottom'])
plt.title("Speed time series")
plt.show()

# %%
plt.hist(df0.rolling(10).mean()["speed:left"])
plt.hist(df0.rolling(10).mean()["speed:center"])
plt.hist(df0.rolling(10).mean()["speed:bottom"])
plt.legend(['speed:left','speed:center','speed:bottom'])
plt.title("Histogram plot for speed from file 1")
plt.show()

# %%
plt.hist(df1.rolling(10).mean()["speed:left"])
plt.hist(df1.rolling(10).mean()["speed:center"])
plt.hist(df1.rolling(10).mean()["speed:bottom"])
plt.legend(['speed:left','speed:center','speed:bottom'])
plt.title("Histogram plot for speed from file 1")
plt.show()
